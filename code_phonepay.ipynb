# %%
import os
import pandas as pd
import json

# %%
BASE_PATH = r"E:\datascience\phone pay mini project\pulse-master\data"

# %%
path = os.path.join(
    BASE_PATH,
    "data", "aggregated", "insurance", "country", "india", "state"
)

# %%
import os

base_path = r"E:\datascience\phone pay mini project\pulse-master\data"

print("Pulse folder exists:", os.path.exists(base_path))

if os.path.exists(base_path):
    print("Contents of pulse:")
    print(os.listdir(base_path))
# Out:
# Pulse folder exists: True
# Contents of pulse:
# ['aggregated', 'map', 'top']

# %%
data_path = r"E:\datascience\phone pay mini project\pulse-master\data"

print("Data folder exists:", os.path.exists(data_path))

if os.path.exists(data_path):
    print(os.listdir(data_path))
# Out:
# Data folder exists: True
# ['aggregated', 'map', 'top']

# %%
insurance_path = r"E:\datascience\phone pay mini project\pulse-master\data\aggregated\insurance\country\india\state"

print("Insurance state folder exists:", os.path.exists(insurance_path))
# Out:
# Insurance state folder exists: True

# %%
import os

search_root = r"E:\datascience\phone pay mini project\pulse-master\data"

for root, dirs, files in os.walk(search_root):
    if root.endswith(r"aggregated\insurance\country\india\state"):
        print("FOUND:")
        print(root)
# Out:
# FOUND:
# E:\datascience\phone pay mini project\pulse-master\data\aggregated\insurance\country\india\state

# %%
import os
import json
import pandas as pd

# Mapping to match map's state spelling
state_name_mapping = {
    "andaman-&-nicobar-islands": "Andaman & Nicobar",
    "andhra-pradesh": "Andhra Pradesh",
    "arunachal-pradesh": "Arunachal Pradesh",
    "assam": "Assam",
    "bihar": "Bihar",
    "chandigarh": "Chandigarh",
    "chhattisgarh": "Chhattisgarh",
    "dadra-&-nagar-haveli-&-daman-&-diu": "Dadra and Nagar Haveli and Daman and Diu",
    "delhi": "NCT of Delhi",
    "goa": "Goa",
    "gujarat": "Gujarat",
    "haryana": "Haryana",
    "himachal-pradesh": "Himachal Pradesh",
    "jammu-&-kashmir": "Jammu & Kashmir",
    "jharkhand": "Jharkhand",
    "karnataka": "Karnataka",
    "kerala": "Kerala",
    "ladakh": "Ladakh",
    "lakshadweep": "Lakshadweep",
    "madhya-pradesh": "Madhya Pradesh",
    "maharashtra": "Maharashtra",
    "manipur": "Manipur",
    "meghalaya": "Meghalaya",
    "mizoram": "Mizoram",
    "nagaland": "Nagaland",
    "odisha": "Odisha",
    "puducherry": "Puducherry",
    "punjab": "Punjab",
    "rajasthan": "Rajasthan",
    "sikkim": "Sikkim",
    "tamil-nadu": "Tamil Nadu",
    "telangana": "Telangana",
    "tripura": "Tripura",
    "uttar-pradesh": "Uttar Pradesh",
    "uttarakhand": "Uttarakhand",
    "west-bengal": "West Bengal"
}

# AGGREGATED INSURANCE
path = r"E:\datascience\phone pay mini project\pulse-master\data\aggregated\insurance\country\india\state"
Agg_state_list = os.listdir(path)

clm = {
    'State': [],
    'Year': [],
    'Quater': [],
    'Insurance_type': [],
    'Insurance_count': [],
    'Insurance_amount': []
}

for i in Agg_state_list:
    p_i = os.path.join(path, i)
    if not os.path.isdir(p_i):
        continue
        
    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)
        if not os.path.isdir(p_j):
            continue
            
        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            if not k.endswith('.json'):
                continue
                
            p_k = os.path.join(p_j, k)
            
            # Safe file reading using context manager
            with open(p_k, 'r') as Data:
                D = json.load(Data)
                
            # Check if transactionData exists and is not None
            transaction_data = D.get('data', {}).get('transactionData')
            if transaction_data:
                for z in transaction_data:
                    Name = z['name']
                    instruments = z.get('paymentInstruments', [])
                    if instruments:
                        count = instruments[0]['count']
                        amount = instruments[0]['amount']
                        
                        clm['Insurance_type'].append(Name)
                        clm['Insurance_count'].append(count)
                        clm['Insurance_amount'].append(amount)
                        clm['State'].append(state_name_mapping.get(i, i))
                        clm['Year'].append(j)
                        clm['Quater'].append(int(k.replace('.json', '')))

Agg_insur = pd.DataFrame(clm)

# %%
Agg_insur
# Out:
#                  State  Year  Quater Insurance_type  Insurance_count  \
# 0    Andaman & Nicobar  2020       2      Insurance                6
# 1    Andaman & Nicobar  2020       3      Insurance               41
# 2    Andaman & Nicobar  2020       4      Insurance              124
# 3    Andaman & Nicobar  2021       1      Insurance              225
# 4    Andaman & Nicobar  2021       2      Insurance              137
# ..                 ...   ...     ...            ...              ...
# 677        West Bengal  2023       4      Insurance            72712
# 678        West Bengal  2024       1      Insurance            79576
# 679        West Bengal  2024       2      Insurance            67048
# 680        West Bengal  2024       3      Insurance            77158
# 681        West Bengal  2024       4      Insurance            91719
#
#      Insurance_amount
# 0              1360.0
# 1             15380.0
# 2            157975.0
# 3            244266.0
# ...

# %%
import os
import json
import pandas as pd

# Path to Aggregated Transaction directory
path = r"E:\datascience\phone pay mini project\pulse-master\data\aggregated\transaction\country\india\state"
Agg_state_list = os.listdir(path)

clm = {
    'State': [],
    'Year': [],
    'Quater': [],
    'Transaction_type': [],
    'Transaction_count': [],
    'Transaction_amount': []
}

for i in Agg_state_list:
    p_i = os.path.join(path, i)
    if not os.path.isdir(p_i):
        continue

    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)
        if not os.path.isdir(p_j):
            continue

        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            if not k.endswith('.json'):
                continue

            p_k = os.path.join(p_j, k)

            # Safe context-managed file handling
            with open(p_k, 'r') as Data:
                D = json.load(Data)

            # Safeguard for missing or null transactionData
            transaction_data = D.get('data', {}).get('transactionData')
            if transaction_data:
                for z in transaction_data:
                    Name = z['name']
                    instruments = z.get('paymentInstruments', [])
                    if instruments:
                        count = instruments[0]['count']
                        amount = instruments[0]['amount']

                        clm['Transaction_type'].append(Name)
                        clm['Transaction_count'].append(count)
                        clm['Transaction_amount'].append(amount)
                        clm['State'].append(state_name_mapping.get(i, i))
                        clm['Year'].append(j)
                        clm['Quater'].append(int(k.replace('.json', '')))

Agg_trans = pd.DataFrame(clm)

# %%
Agg_trans
# Out:
#                   State  Year  Quater          Transaction_type  \
# 0     Andaman & Nicobar  2018       1  Recharge & bill payments
# 1     Andaman & Nicobar  2018       1     Peer-to-peer payments
# 2     Andaman & Nicobar  2018       1         Merchant payments
# 3     Andaman & Nicobar  2018       1        Financial Services
# 4     Andaman & Nicobar  2018       1                    Others
# ...                 ...   ...     ...                       ...
# 5029        West Bengal  2024       4         Merchant payments
# 5030        West Bengal  2024       4     Peer-to-peer payments
# 5031        West Bengal  2024       4  Recharge & bill payments
# 5032        West Bengal  2024       4        Financial Services
# 5033        West Bengal  2024       4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# 1                  1871        1.213866e+07
# 2                   298        4.525072e+05
# ...

# %%
import os
import json
import pandas as pd

# Path to Aggregated User directory
path = r"E:\datascience\phone pay mini project\pulse-master\data\aggregated\user\country\india\state"
Agg_state_list = os.listdir(path)

clm = {
    'State': [],
    'Year': [],
    'Quater': [],
    'Brands': [],
    'Transaction_count': [],
    'Percentage': []
}

for i in Agg_state_list:
    p_i = os.path.join(path, i)
    if not os.path.isdir(p_i):
        continue

    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)
        if not os.path.isdir(p_j):
            continue

        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            if not k.endswith('.json'):
                continue

            p_k = os.path.join(p_j, k)

            with open(p_k, 'r') as Data:
                D = json.load(Data)

            # Safely access usersByDevice (Handles None values for Q2 2022 onwards)
            user_data = D.get('data')
            if user_data and user_data.get('usersByDevice'):
                for z in user_data['usersByDevice']:
                    brand = z.get('brand')
                    count = z.get('count')
                    percentage = z.get('percentage')

                    clm['Brands'].append(brand)
                    clm['Transaction_count'].append(count)
                    clm['Percentage'].append(percentage)
                    clm['State'].append(state_name_mapping.get(i, i))
                    clm['Year'].append(j)
                    clm['Quater'].append(int(k.replace('.json', '')))

Agg_user = pd.DataFrame(clm)

# %%
Agg_user
# Out:
#                   State  Year  Quater   Brands  Transaction_count  Percentage
# 0     Andaman & Nicobar  2018       1   Xiaomi               1665    0.247033
# 1     Andaman & Nicobar  2018       1  Samsung               1445    0.214392
# 2     Andaman & Nicobar  2018       1     Vivo                982    0.145697
# 3     Andaman & Nicobar  2018       1     Oppo                501    0.074332
# 4     Andaman & Nicobar  2018       1  OnePlus                332    0.049258
# ...                 ...   ...     ...      ...                ...         ...
# 6727        West Bengal  2022       1   Lenovo             330017    0.015056
# 6728        West Bengal  2022       1  Infinix             284678    0.012987
# 6729        West Bengal  2022       1     Asus             280347    0.012790
# 6730        West Bengal  2022       1    Apple             277752    0.012671
# 6731        West Bengal  2022       1   Others            2196334    0.100199
#
# [6732 rows x 6 columns]

# %%
import os
import json
import pandas as pd

# Path to Map Insurance directory
path = r"E:\datascience\phone pay mini project\pulse-master\data\map\insurance\hover\country\india\state"
Agg_state_list = os.listdir(path)

clm = {
    'State': [],
    'Year': [],
    'Quater': [],
    'Districts': [],
    'Insurance_count': [],
    'Insurance_amount': []
}

for i in Agg_state_list:
    p_i = os.path.join(path, i)
    if not os.path.isdir(p_i):
        continue

    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)
        if not os.path.isdir(p_j):
            continue

        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            if not k.endswith('.json'):
                continue

            p_k = os.path.join(p_j, k)

            with open(p_k, 'r') as Data:
                D = json.load(Data)

            # Safely check for hoverDataList
            hover_data = D.get('data', {}).get('hoverDataList')
            if hover_data:
                for z in hover_data:
                    name = z.get('name', '').title()  # Clean district name casing
                    metrics = z.get('metric', [])
                    
                    if metrics:
                        count = metrics[0].get('count')
                        amount = metrics[0].get('amount')

                        clm['Districts'].append(name)
                        clm['Insurance_count'].append(count)
                        clm['Insurance_amount'].append(amount)
                        clm['State'].append(state_name_mapping.get(i, i))
                        clm['Year'].append(j)
                        clm['Quater'].append(int(k.replace('.json', '')))

Map_insur = pd.DataFrame(clm)

# %%
Map_insur
# Out:
#                    State  Year  Quater                          Districts  \
# 0      Andaman & Nicobar  2020       2             South Andaman District
# 1      Andaman & Nicobar  2020       2                  Nicobars District
# 2      Andaman & Nicobar  2020       3  North And Middle Andaman District
# 3      Andaman & Nicobar  2020       3             South Andaman District
# 4      Andaman & Nicobar  2020       3                  Nicobars District
# ...                  ...   ...     ...                                ...
# 13871        West Bengal  2024       4                Alipurduar District
# 13872        West Bengal  2024       4         Paschim Bardhaman District
# 13873        West Bengal  2024       4                     Nadia District
# 13874        West Bengal  2024       4                   Birbhum District
# 13875        West Bengal  2024       4           Purba Medinipur District
#
#        Insurance_count  Insurance_amount
# ...

# %%
import os
import json
import pandas as pd

# Path to Map Transaction directory
path = r"E:\datascience\phone pay mini project\pulse-master\data\map\transaction\hover\country\india\state"
Agg_state_list = os.listdir(path)

clm = {
    'State': [],
    'Year': [],
    'Quater': [],
    'Districts': [],
    'Transaction_count': [],
    'Transaction_amount': []
}

for i in Agg_state_list:
    p_i = os.path.join(path, i)
    if not os.path.isdir(p_i):
        continue

    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)
        if not os.path.isdir(p_j):
            continue

        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            if not k.endswith('.json'):
                continue

            p_k = os.path.join(p_j, k)

            with open(p_k, 'r') as Data:
                D = json.load(Data)

            # Safely check for hoverDataList
            hover_data = D.get('data', {}).get('hoverDataList')
            if hover_data:
                for z in hover_data:
                    name = z.get('name', '').title()  # Clean district name casing
                    metrics = z.get('metric', [])

                    if metrics:
                        count = metrics[0].get('count')
                        amount = metrics[0].get('amount')

                        clm['Districts'].append(name)
                        clm['Transaction_count'].append(count)
                        clm['Transaction_amount'].append(amount)
                        clm['State'].append(state_name_mapping.get(i, i))
                        clm['Year'].append(j)
                        clm['Quater'].append(int(k.replace('.json', '')))

Map_trans = pd.DataFrame(clm)

# %%
Map_trans
# Out:
#                    State  Year  Quater                          Districts  \
# 0      Andaman & Nicobar  2018       1  North And Middle Andaman District
# 1      Andaman & Nicobar  2018       1             South Andaman District
# 2      Andaman & Nicobar  2018       1                  Nicobars District
# 3      Andaman & Nicobar  2018       2  North And Middle Andaman District
# 4      Andaman & Nicobar  2018       2             South Andaman District
# ...                  ...   ...     ...                                ...
# 20599        West Bengal  2024       4                Alipurduar District
# 20600        West Bengal  2024       4         Paschim Bardhaman District
# 20601        West Bengal  2024       4                     Nadia District
# 20602        West Bengal  2024       4                   Birbhum District
# 20603        West Bengal  2024       4           Purba Medinipur District
#
#        Transaction_count  Transaction_amount
# ...

# %%
import os
import json
import pandas as pd

# Path to Map User directory
path = r"E:\datascience\phone pay mini project\pulse-master\data\map\user\hover\country\india\state"
Agg_state_list = os.listdir(path)

clm = {
    'State': [],
    'Year': [],
    'Quater': [],
    'Districts': [],
    'RegisteredUser': [],
    'AppOpens': []
}

for i in Agg_state_list:
    p_i = os.path.join(path, i)
    if not os.path.isdir(p_i):
        continue

    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)
        if not os.path.isdir(p_j):
            continue

        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            if not k.endswith('.json'):
                continue

            p_k = os.path.join(p_j, k)

            with open(p_k, 'r') as Data:
                D = json.load(Data)

            # Safely check for hoverData dictionary
            hover_data = D.get('data', {}).get('hoverData')
            if hover_data and isinstance(hover_data, dict):
                for district_name, metrics in hover_data.items():
                    registered_user = metrics.get('registeredUsers', 0)
                    app_opens = metrics.get('appOpens', 0)

                    clm['Districts'].append(district_name.title())
                    clm['RegisteredUser'].append(registered_user)
                    clm['AppOpens'].append(app_opens)
                    clm['State'].append(state_name_mapping.get(i, i))
                    clm['Year'].append(j)
                    clm['Quater'].append(int(k.replace('.json', '')))

Map_user = pd.DataFrame(clm)

# %%
Map_user
# Out:
#                    State  Year  Quater                          Districts  \
# 0      Andaman & Nicobar  2018       1  North And Middle Andaman District
# 1      Andaman & Nicobar  2018       1             South Andaman District
# 2      Andaman & Nicobar  2018       1                  Nicobars District
# 3      Andaman & Nicobar  2018       2  North And Middle Andaman District
# 4      Andaman & Nicobar  2018       2             South Andaman District
# ...                  ...   ...     ...                                ...
# 20603        West Bengal  2024       4                Alipurduar District
# 20604        West Bengal  2024       4         Paschim Bardhaman District
# 20605        West Bengal  2024       4                     Nadia District
# 20606        West Bengal  2024       4                   Birbhum District
# 20607        West Bengal  2024       4           Purba Medinipur District
#
#        RegisteredUser   AppOpens
# 0                 632          0
# ...

# %%
import os
import json
import pandas as pd

# Path to Top Insurance directory
path = r"E:\datascience\phone pay mini project\pulse-master\data\top\insurance\country\india\state"
Agg_state_list = os.listdir(path)

clm = {
    'State': [],
    'Year': [],
    'Quater': [],
    'Pincodes': [],
    'Insurance_count': [],
    'Insurance_amount': []
}

for i in Agg_state_list:
    p_i = os.path.join(path, i)
    if not os.path.isdir(p_i):
        continue

    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)
        if not os.path.isdir(p_j):
            continue

        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            if not k.endswith('.json'):
                continue

            p_k = os.path.join(p_j, k)

            with open(p_k, 'r') as Data:
                D = json.load(Data)

            # Safely get pincodes list from data
            pincodes_data = D.get('data', {}).get('pincodes')
            if pincodes_data:
                for z in pincodes_data:
                    entity_name = str(z.get('entityName', ''))
                    metric = z.get('metric', {})
                    count = metric.get('count')
                    amount = metric.get('amount')

                    clm['Pincodes'].append(entity_name)
                    clm['Insurance_count'].append(count)
                    clm['Insurance_amount'].append(amount)
                    clm['State'].append(state_name_mapping.get(i, i))
                    clm['Year'].append(j)
                    clm['Quater'].append(int(k.replace('.json', '')))

Top_insur = pd.DataFrame(clm)

# %%
Top_insur
# Out:
#                   State  Year  Quater Pincodes  Insurance_count  \
# 0     Andaman & Nicobar  2020       2   744301                3
# 1     Andaman & Nicobar  2020       2   744104                2
# 2     Andaman & Nicobar  2020       2   744101                1
# 3     Andaman & Nicobar  2020       3   744112                9
# 4     Andaman & Nicobar  2020       3   744105                7
# ...                 ...   ...     ...      ...              ...
# 6663        West Bengal  2024       4   711101              713
# 6664        West Bengal  2024       4   700091              642
# 6665        West Bengal  2024       4   700150              627
# 6666        West Bengal  2024       4   700039              619
# 6667        West Bengal  2024       4   700156              574
#
#       Insurance_amount
# 0                565.0
# 1                513.0
# 2                282.0
# 3               3432.0
# 4               3948.0
# ...                ...
# 6663          750354.0
# ...

# %%
import os
import json
import pandas as pd

# Path to Top Transaction directory
path = r"E:\datascience\phone pay mini project\pulse-master\data\top\transaction\country\india\state"
Agg_state_list = os.listdir(path)

clm = {
    'State': [],
    'Year': [],
    'Quater': [],
    'Pincodes': [],
    'Transaction_count': [],
    'Transaction_amount': []
}

for i in Agg_state_list:
    p_i = os.path.join(path, i)
    if not os.path.isdir(p_i):
        continue

    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)
        if not os.path.isdir(p_j):
            continue

        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            if not k.endswith('.json'):
                continue

            p_k = os.path.join(p_j, k)

            with open(p_k, 'r') as Data:
                D = json.load(Data)

            # Safely get pincodes list from data
            pincodes_data = D.get('data', {}).get('pincodes')
            if pincodes_data:
                for z in pincodes_data:
                    entity_name = str(z.get('entityName', ''))
                    metric = z.get('metric', {})
                    count = metric.get('count')
                    amount = metric.get('amount')

                    clm['Pincodes'].append(entity_name)
                    clm['Transaction_count'].append(count)
                    clm['Transaction_amount'].append(amount)
                    clm['State'].append(state_name_mapping.get(i, i))
                    clm['Year'].append(j)
                    clm['Quater'].append(int(k.replace('.json', '')))

Top_trans = pd.DataFrame(clm)

# %%
Top_trans
# Out:
#                   State  Year  Quater Pincodes  Transaction_count  \
# 0     Andaman & Nicobar  2018       1   744101               1622
# 1     Andaman & Nicobar  2018       1   744103               1223
# 2     Andaman & Nicobar  2018       1   744102                969
# 3     Andaman & Nicobar  2018       1   744105                685
# 4     Andaman & Nicobar  2018       1   744104                340
# ...                 ...   ...     ...      ...                ...
# 9994        West Bengal  2024       4   711101            6753348
# 9995        West Bengal  2024       4   700059            6662715
# 9996        West Bengal  2024       4   700039            6575693
# 9997        West Bengal  2024       4   734001            6432082
# 9998        West Bengal  2024       4   733134            6313560
#
#       Transaction_amount
# 0           2.769298e+06
# 1           2.238042e+06
# 2           3.519060e+06
# 3           1.298561e+06
# 4           1.039715e+06
# ...

# %%
import os
import json
import pandas as pd

# Path to Top User directory
path = r"E:\datascience\phone pay mini project\pulse-master\data\top\user\country\india\state"
Agg_state_list = os.listdir(path)

clm = {
    'State': [],
    'Year': [],
    'Quater': [],
    'Pincodes': [],
    'RegisteredUser': []
}

for i in Agg_state_list:
    p_i = os.path.join(path, i)
    if not os.path.isdir(p_i):
        continue

    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)
        if not os.path.isdir(p_j):
            continue

        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            if not k.endswith('.json'):
                continue

            p_k = os.path.join(p_j, k)

            with open(p_k, 'r') as Data:
                D = json.load(Data)

            # Safely get pincodes list from data
            pincodes_data = D.get('data', {}).get('pincodes')
            if pincodes_data:
                for z in pincodes_data:
                    pincode = str(z.get('name', ''))
                    registered_user = z.get('registeredUsers', 0)

                    clm['Pincodes'].append(pincode)
                    clm['RegisteredUser'].append(registered_user)
                    clm['State'].append(state_name_mapping.get(i, i))
                    clm['Year'].append(j)
                    clm['Quater'].append(int(k.replace('.json', '')))

Top_user = pd.DataFrame(clm)

# %%
Top_user
# Out:
#                   State  Year  Quater Pincodes  RegisteredUser
# 0     Andaman & Nicobar  2018       1   744103            1608
# 1     Andaman & Nicobar  2018       1   744101            1108
# 2     Andaman & Nicobar  2018       1   744105            1075
# 3     Andaman & Nicobar  2018       1   744102            1006
# 4     Andaman & Nicobar  2018       1   744104             272
# ...                 ...   ...     ...      ...             ...
# 9995        West Bengal  2024       4   733134          169596
# 9996        West Bengal  2024       4   700059          169448
# 9997        West Bengal  2024       4   711302          146034
# 9998        West Bengal  2024       4   700150          142151
# 9999        West Bengal  2024       4   711106          142077
#
# [10000 rows x 5 columns]

# %%
import mysql.connector

# Establish MySQL Connection
mydb = mysql.connector.connect(
    host='localhost',
    user='root',
    password='Jaya@1608',
    database='phonepay'
)
cursor = mydb.cursor()

# %%
# 1. AGGREGATED INSURANCE
cursor.execute("DROP TABLE IF EXISTS aggregated_insurance")
cursor.execute("""
CREATE TABLE aggregated_insurance (
    State VARCHAR(100),
    Year INT,
    Quarter INT,
    Insurance_type VARCHAR(100),
    Insurance_count BIGINT,
    Insurance_amount DOUBLE
)
""")

query_agg_insur = """
INSERT INTO aggregated_insurance (State, Year, Quarter, Insurance_type, Insurance_count, Insurance_amount)
VALUES (%s, %s, %s, %s, %s, %s)
"""
values_agg_insur = [tuple(x) for x in Agg_insur[['State', 'Year', 'Quater', 'Insurance_type', 'Insurance_count', 'Insurance_amount']].to_numpy()]
cursor.executemany(query_agg_insur, values_agg_insur)
# Out:
# All tables successfully dropped, re-created, and populated in MySQL!

# %%
# 2. AGGREGATED TRANSACTION

cursor.execute("DROP TABLE IF EXISTS aggregated_transaction")
cursor.execute("""
CREATE TABLE aggregated_transaction (
    State VARCHAR(100),
    Year INT,
    Quarter INT,
    Transaction_type VARCHAR(100),
    Transaction_count BIGINT,
    Transaction_amount DOUBLE
)
""")

query_agg_trans = """
INSERT INTO aggregated_transaction (State, Year, Quarter, Transaction_type, Transaction_count, Transaction_amount)
VALUES (%s, %s, %s, %s, %s, %s)
"""
values_agg_trans = [tuple(x) for x in Agg_trans[['State', 'Year', 'Quater', 'Transaction_type', 'Transaction_count', 'Transaction_amount']].to_numpy()]
cursor.executemany(query_agg_trans, values_agg_trans)

# %%
# 3. AGGREGATED USER
cursor.execute("DROP TABLE IF EXISTS aggregated_user")
cursor.execute("""
CREATE TABLE aggregated_user (
    State VARCHAR(100),
    Year INT,
    Quarter INT,
    Brands VARCHAR(100),
    Transaction_count BIGINT,
    Percentage FLOAT
)
""")

query_agg_user = """
INSERT INTO aggregated_user (State, Year, Quarter, Brands, Transaction_count, Percentage)
VALUES (%s, %s, %s, %s, %s, %s)
"""
values_agg_user = [tuple(x) for x in Agg_user[['State', 'Year', 'Quater', 'Brands', 'Transaction_count', 'Percentage']].to_numpy()]
cursor.executemany(query_agg_user, values_agg_user)

# %%
# 4. MAP INSURANCE
cursor.execute("DROP TABLE IF EXISTS map_insurance")
cursor.execute("""
CREATE TABLE map_insurance (
    State VARCHAR(100),
    Year INT,
    Quarter INT,
    District VARCHAR(100),
    Insurance_count BIGINT,
    Insurance_amount DOUBLE
)
""")

query_map_insur = """
INSERT INTO map_insurance (State, Year, Quarter, District, Insurance_count, Insurance_amount)
VALUES (%s, %s, %s, %s, %s, %s)
"""
values_map_insur = [tuple(x) for x in Map_insur[['State', 'Year', 'Quater', 'Districts', 'Insurance_count', 'Insurance_amount']].to_numpy()]
cursor.executemany(query_map_insur, values_map_insur)

# %%
# 5. MAP TRANSACTION
cursor.execute("DROP TABLE IF EXISTS map_transaction")
cursor.execute("""
CREATE TABLE map_transaction (
    State VARCHAR(100),
    Year INT,
    Quarter INT,
    District VARCHAR(100),
    Transaction_count BIGINT,
    Transaction_amount DOUBLE
)
""")

query_map_trans = """
INSERT INTO map_transaction (State, Year, Quarter, District, Transaction_count, Transaction_amount)
VALUES (%s, %s, %s, %s, %s, %s)
"""
values_map_trans = [tuple(x) for x in Map_trans[['State', 'Year', 'Quater', 'Districts', 'Transaction_count', 'Transaction_amount']].to_numpy()]
cursor.executemany(query_map_trans, values_map_trans)

# %%
# 6. MAP USER
cursor.execute("DROP TABLE IF EXISTS map_user")
cursor.execute("""
CREATE TABLE map_user (
    State VARCHAR(100),
    Year INT,
    Quarter INT,
    District VARCHAR(100),
    RegisteredUser BIGINT,
    AppOpens BIGINT
)
""")

query_map_user = """
INSERT INTO map_user (State, Year, Quarter, District, RegisteredUser, AppOpens)
VALUES (%s, %s, %s, %s, %s, %s)
"""
values_map_user = [tuple(x) for x in Map_user[['State', 'Year', 'Quater', 'Districts', 'RegisteredUser', 'AppOpens']].to_numpy()]
cursor.executemany(query_map_user, values_map_user)

# %%
# 7. TOP INSURANCE
cursor.execute("DROP TABLE IF EXISTS top_insurance")
cursor.execute("""
CREATE TABLE top_insurance (
    State VARCHAR(100),
    Year INT,
    Quarter INT,
    Pincodes VARCHAR(10),
    Insurance_count BIGINT,
    Insurance_amount DOUBLE
)
""")

query_top_insur = """
INSERT INTO top_insurance (State, Year, Quarter, Pincodes, Insurance_count, Insurance_amount)
VALUES (%s, %s, %s, %s, %s, %s)
"""
values_top_insur = [tuple(x) for x in Top_insur[['State', 'Year', 'Quater', 'Pincodes', 'Insurance_count', 'Insurance_amount']].to_numpy()]
cursor.executemany(query_top_insur, values_top_insur)

# %%
# 8. TOP TRANSACTION
cursor.execute("DROP TABLE IF EXISTS top_transaction")
cursor.execute("""
CREATE TABLE top_transaction (
    State VARCHAR(100),
    Year INT,
    Quarter INT,
    Pincodes VARCHAR(10),
    Transaction_count BIGINT,
    Transaction_amount DOUBLE
)
""")

query_top_trans = """
INSERT INTO top_transaction (State, Year, Quarter, Pincodes, Transaction_count, Transaction_amount)
VALUES (%s, %s, %s, %s, %s, %s)
"""
values_top_trans = [tuple(x) for x in Top_trans[['State', 'Year', 'Quater', 'Pincodes', 'Transaction_count', 'Transaction_amount']].to_numpy()]
cursor.executemany(query_top_trans, values_top_trans)

# %%
# 9. TOP USER
cursor.execute("DROP TABLE IF EXISTS top_user")
cursor.execute("""
CREATE TABLE top_user (
    State VARCHAR(100),
    Year INT,
    Quarter INT,
    Pincodes VARCHAR(10),
    RegisteredUser BIGINT
)
""")

query_top_user = """
INSERT INTO top_user (State, Year, Quarter, Pincodes, RegisteredUser)
VALUES (%s, %s, %s, %s, %s)
"""
values_top_user = [tuple(x) for x in Top_user[['State', 'Year', 'Quater', 'Pincodes', 'RegisteredUser']].to_numpy()]
cursor.executemany(query_top_user, values_top_user)

# %%
# ---------------------------------------------------------
# COMMIT & CLOSE
# ---------------------------------------------------------
mydb.commit()
cursor.close()
mydb.close()
print("All tables successfully dropped, re-created, and populated in MySQL!")
# Out:
# All tables successfully dropped, re-created, and populated in MySQL!
